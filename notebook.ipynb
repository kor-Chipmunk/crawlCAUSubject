# %%
import requests, json
from bs4 import BeautifulSoup

from openpyxl import load_workbook
from openpyxl import Workbook

# %%
URL = "https://mportal.cau.ac.kr/std/usk/sUskSif001/selectParam.ajax"

campfg = "1"
params = {'year': "2019", 'campfg': campfg, 'course': "3", 'gb': "3"}
headers = {'Content-Type': 'application/json; charset=utf-8'}

res = requests.post(URL, headers=headers, data=json.dumps(params))

resToJson = res.json()

# %%
colgList = []

for menu in resToJson['selectColg']:
    if menu['deptcd'] == None:
        continue
    
    insertDict = {'name': menu['deptkornm'], 'code': menu['deptcd'], 'campcode': menu['campfg']}
    
    colgList.append(insertDict)

print (colgList)
# Out:
# [{'name': '교양', 'code': '00000', 'campcode': '9'}, {'name': '연계전공', 'code': 'LNK', 'campcode': '8'}, {'name': '융합전공', 'code': 'FSN', 'campcode': '7'}, {'name': '인문대학(2011)', 'code': '3A100', 'campcode': '0'}, {'name': '사회과학대학(2011)', 'code': '3A300', 'campcode': '0'}, {'name': '사범대학(2011)', 'code': '3A500', 'campcode': '1'}, {'name': '자연과학대학(2011)', 'code': '3B100', 'campcode': '0'}, {'name': '공과대학(2011)', 'code': '3B300', 'campcode': '0'}, {'name': '창의ICT공과대학', 'code': '3B400', 'campcode': '0'}, {'name': '소프트웨어대학', 'code': '3B500', 'campcode': '1'}, {'name': '경영경제대학(2011)', 'code': '3C100', 'campcode': '0'}, {'name': '약학대학(2011)', 'code': '3D100', 'campcode': '1'}, {'name': '적십자간호대학(2011)', 'code': '3D500', 'campcode': '1'}, {'name': '적십자간호대학', 'code': '3D600', 'campcode': '1'}, {'name': '교양학부대학', 'code': '3F300', 'campcode': '0'}, {'name': '다빈치교양대학', 'code': '3F400', 'campcode': '0'}, {'name': '예술대학(2011)', 'code': '3E100', 'campcode': '0'}, {'name': '의과대학(2011)', 'code': '3D300', 'campcode': '1'}, {'name': '문과대학', 'code': '30140', 'campcode': '1'}, {'name': '자연과학대학', 'code': '30180', 'campcode': '1'}, {'name': '공과대학', 'code': '30220', 'campcode': '1'}, {'name': '사범대학', 'code': '30270', 'campcode': '1'}, {'name': '법과대학', 'code': '30290', 'campcode': '1'}, {'name': '정경대학', 'code': '30300', 'campcode': '1'}, {'name': '경영대학', 'code': '30330', 'campcode': '1'}, {'name': '약학대학', 'code': '30390', 'campcode': '1'}, {'name': '의과대학', 'code': '30410', 'campcode': '1'}, {'name': '미디어공연영상대학', 'code': '30640', 'campcode': '1'}, {'name': '자유전공학부.', 'code': '30680', 'campcode': '1'}, {'name': '공공인재학부.', 'code': '30690', 'campcode': '1'}, {'name': '글로벌지식학부.', 'code': '30700', 'campcode': '1'}, {'name': '교양학부대학(2011)', 'code': '3M100', 'campcode': '0'}]

# %%
colg = colgList[2]

URL = "https://mportal.cau.ac.kr/std/usk/sUskSif001/selectSust.ajax"
params = {'year': "2019", 'campfg': colg['campcode'], 'course': "3", 'gb': "3", 'colgcd': colg['code'], 'shtm': "2"}
headers = {'Content-Type': 'application/json; charset=utf-8'}

res = requests.post(URL, headers=headers, data=json.dumps(params))
resToJson = res.json()

# %%
susts = []

for detailSust in resToJson['selectSust']:
    insertSust = {'campcode': detailSust['camp'], 'name': detailSust['nm'], 'code': detailSust['deptcd']}
    
    susts.append(insertSust)

print(susts)
# Out:
# [{'campcode': '0', 'name': '금융공학융합전공', 'code': '38502'}, {'campcode': '0', 'name': '문화콘텐츠융합전공', 'code': '38503'}, {'campcode': '0', 'name': '창업학융합전공', 'code': '38504'}, {'campcode': '0', 'name': '게임·인터렉티브미디어융합전공', 'code': '38505'}, {'campcode': '0', 'name': '소프트웨어·인문융합전공', 'code': '38506'}, {'campcode': '0', 'name': '사이버보안융합전공', 'code': '38507'}, {'campcode': '0', 'name': '테크놀로지아트융합전공', 'code': '38508'}, {'campcode': '0', 'name': '소프트웨어벤처 융합전공', 'code': '38509'}]

# %%
exportTable = []
exportTable.append(['전공', '학년', '이수구분', '과목번호-분반', '과목명', '담당교수', '학점', '시간', '강의실/강의시간', '개설학과', '유의사항'])

# %%
URL = "https://mportal.cau.ac.kr/std/usk/sUskSif001/selectSbjt.ajax"
params = {"year":"2019","campfg":campfg,"course":"3","gb":"3","colgcd":colg['code'],"shtm":"2","sust":susts[0]['code'],"search_gb":colg['code'],"kornm":""}
headers = {'Content-Type': 'application/json; charset=utf-8'}

res = requests.post(URL, headers=headers, data=json.dumps(params))
resToJson = res.json()

print (resToJson)
# Out:
# {'selectSust': [{'colgnm': '경영경제대학', 'sustnm': '경영학전공', 'shyr': '1', 'pobtnm': '전공기초', 'sbjtclss': '01307-02', 'sbjtclsslk': '01307-02', 'sbjtno': '01307', 'clssno': '02', 'clssnm': '경영통계학 (영어A강의)', 'clssnmlk': '경영통계학 (영어A강의)', 'pnt': '3-3', 'profnm': '김영일', 'profnmlk': '김영일', 'clsefg': None, 'ltbdrm': '화7,8,9 / 310관 611호 &#60;강의실&#62;', 'remk': ' ', 'campcd': '1', 'sust': '3C115', 'corscd': '학사', 'comsut': None, 'shyr2': '1', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '060152', 'sb': '01307', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '자연과학대학', 'sustnm': '수학과', 'shyr': '1', 'pobtnm': '전공기초', 'sbjtclss': '53831-01', 'sbjtclsslk': '53831-01', 'sbjtno': '53831', 'clssno': '01', 'clssnm': '미분적분학(2)', 'clssnmlk': '미분적분학(2)', 'pnt': '3-3', 'profnm': '김선철', 'profnmlk': '김선철', 'clsefg': None, 'ltbdrm': '화2 / 목1,2 / 102관(약학대학 및 R&D센터) 108호 &#60;강의실&#62;', 'remk': ' ', 'campcd': '1', 'sust': '3B140', 'corscd': '학사', 'comsut': None, 'shyr2': '1', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '065993', 'sb': '53831', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '소프트웨어대학', 'sustnm': '소프트웨어학부', 'shyr': '1', 'pobtnm': '전공', 'sbjtclss': '49361-01', 'sbjtclsslk': '49361-01', 'sbjtno': '49361', 'clssno': '01', 'clssnm': '비쥬얼프로그래밍', 'clssnmlk': '비쥬얼프로그래밍', 'pnt': '3-3', 'profnm': '김승태', 'profnmlk': '김승태', 'clsefg': None, 'ltbdrm': '목9,10,11 / 208관(제2공학관) 601호 &#60;컴퓨터공학부 PC 실습실&#62;', 'remk': ' 자과생수강불가,SCSC,비전공자전용', 'campcd': '1', 'sust': '3B510', 'corscd': '학사', 'comsut': None, 'shyr2': '1', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '010253', 'sb': '49361', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '소프트웨어대학', 'sustnm': '소프트웨어학부', 'shyr': '1', 'pobtnm': '전공기초', 'sbjtclss': '47710-06', 'sbjtclsslk': '47710-06', 'sbjtno': '47710', 'clssno': '06', 'clssnm': '프로그래밍', 'clssnmlk': '프로그래밍', 'pnt': '3-4', 'profnm': '이남규', 'profnmlk': '이남규', 'clsefg': None, 'ltbdrm': '화9,10 / 목9,10 / 310관 620호 &#60;강의실&#62; / B311호 &#60;SW융합 PC실3&#62;', 'remk': ' 자과생수강불가,비전공자전용', 'campcd': '1', 'sust': '3B510', 'corscd': '학사', 'comsut': None, 'shyr2': '1', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '095155', 'sb': '47710', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '소프트웨어대학', 'sustnm': '소프트웨어학부', 'shyr': '1', 'pobtnm': '전공기초', 'sbjtclss': '47710-07', 'sbjtclsslk': '47710-07', 'sbjtno': '47710', 'clssno': '07', 'clssnm': '프로그래밍 (영어A강의)', 'clssnmlk': '프로그래밍 (영어A강의)', 'pnt': '3-4', 'profnm': None, 'profnmlk': None, 'clsefg': None, 'ltbdrm': '수7,8,9,10 / 208관(제2공학관) 601호 &#60;컴퓨터공학부 PC 실습실&#62;', 'remk': ' 자과생수강불가,비전공자전용', 'campcd': '1', 'sust': '3B510', 'corscd': '학사', 'comsut': None, 'shyr2': '1', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '999999', 'sb': '47710', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '경영경제대학', 'sustnm': '경제학부(서울)', 'shyr': '2', 'pobtnm': '전공필수', 'sbjtclss': '00736-01', 'sbjtclsslk': '00736-01', 'sbjtno': '00736', 'clssno': '01', 'clssnm': '거시경제학', 'clssnmlk': '거시경제학', 'pnt': '3-3', 'profnm': '허식', 'profnmlk': '허식', 'clsefg': None, 'ltbdrm': '월(15:00~16:15) / 수(15:00~16:15) / 310관 722호 &#60;강의실&#62;', 'remk': ' ', 'campcd': '1', 'sust': '3C130', 'corscd': '학사', 'comsut': None, 'shyr2': '2', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '064393', 'sb': '00736', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '경영경제대학', 'sustnm': '경제학부(서울)', 'shyr': '2', 'pobtnm': '전공필수', 'sbjtclss': '00736-02', 'sbjtclsslk': '00736-02', 'sbjtno': '00736', 'clssno': '02', 'clssnm': '거시경제학', 'clssnmlk': '거시경제학', 'pnt': '3-3', 'profnm': '김지욱', 'profnmlk': '김지욱', 'clsefg': None, 'ltbdrm': '월(10:30~11:45) / 수(10:30~11:45) / 310관 704호 &#60;강의실&#62;', 'remk': ' ', 'campcd': '1', 'sust': '3C130', 'corscd': '학사', 'comsut': None, 'shyr2': '2', 'pobtfg': 'N', 'cnt': 1, 'n': ' ', 'empno': '069191', 'sb': '00736', 'shtm': '2', 'flx': None, 'fileusefg': None}, {'colgnm': '경영경제대학', 'sustnm': '경제학부(서울)', 'shyr': '2', 'pobtnm': '전공필수', 'sbjtclss': '00736-03', 'sbjtclsslk': '00736-03', 'sbjtno': '00736', 'cls ...

# %%
for subject in resToJson['selectSust']:
    exportTable.append([susts[0]['name']
                        , subject['shyr'] \
                        , subject['pobtnm'] \
                        , subject['sbjtclss'] \
                        , subject['clssnm'] \
                        , subject['profnm'] \
                        , subject['pnt'].split('-')[0] \
                        , subject['pnt'].split('-')[1] \
                        , subject['ltbdrm'] \
                        , '' if subject['sustnm'] == None else subject['sustnm']
                        , subject['remk']])

# %%
exportTable
# Out:
# [['전공',
#   '학년',
#   '이수구분',
#   '과목번호-분반',
#   '과목명',
#   '담당교수',
#   '학점',
#   '시간',
#   '강의실/강의시간',
#   '개설학과',
#   '유의사항'],
#  ['금융공학융합전공',
#   '1',
#   '전공기초',
#   '01307-02',
#   '경영통계학 (영어A강의)',
#   '김영일',
#   '3',
#   '3',
#   '화7,8,9 / 310관 611호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '1',
#   '전공기초',
#   '53831-01',
#   '미분적분학(2)',
#   '김선철',
#   '3',
#   '3',
#   '화2 / 목1,2 / 102관(약학대학 및 R&D센터) 108호 &#60;강의실&#62;',
#   '수학과',
#   ' '],
#  ['금융공학융합전공',
#   '1',
#   '전공',
#   '49361-01',
#   '비쥬얼프로그래밍',
#   '김승태',
#   '3',
#   '3',
#   '목9,10,11 / 208관(제2공학관) 601호 &#60;컴퓨터공학부 PC 실습실&#62;',
#   '소프트웨어학부',
#   ' 자과생수강불가,SCSC,비전공자전용'],
#  ['금융공학융합전공',
#   '1',
#   '전공기초',
#   '47710-06',
#   '프로그래밍',
#   '이남규',
#   '3',
#   '4',
#   '화9,10 / 목9,10 / 310관 620호 &#60;강의실&#62; / B311호 &#60;SW융합 PC실3&#62;',
#   '소프트웨어학부',
#   ' 자과생수강불가,비전공자전용'],
#  ['금융공학융합전공',
#   '1',
#   '전공기초',
#   '47710-07',
#   '프로그래밍 (영어A강의)',
#   None,
#   '3',
#   '4',
#   '수7,8,9,10 / 208관(제2공학관) 601호 &#60;컴퓨터공학부 PC 실습실&#62;',
#   '소프트웨어학부',
#   ' 자과생수강불가,비전공자전용'],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '00736-01',
#   '거시경제학',
#   '허식',
#   '3',
#   '3',
#   '월(15:00~16:15) / 수(15:00~16:15) / 310관 722호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '00736-02',
#   '거시경제학',
#   '김지욱',
#   '3',
#   '3',
#   '월(10:30~11:45) / 수(10:30~11:45) / 310관 704호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '00736-03',
#   '거시경제학',
#   '류덕현',
#   '3',
#   '3',
#   '월(13:30~14:45) / 수(13:30~14:45) / 310관 311호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '00736-05',
#   '거시경제학',
#   '김배근',
#   '3',
#   '3',
#   '화(15:00~16:15) / 목(15:00~16:15) / 310관 925호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '00736-04',
#   '거시경제학 (영어A강의)',
#   '송원호',
#   '3',
#   '3',
#   '화(09:00~10:15) / 목(09:00~10:15) / 310관 311호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '01478-01',
#   '경제통계학',
#   '송정석',
#   '3',
#   '3',
#   '화(09:00~10:15) / 목(09:00~10:15) / 310관 722호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '01478-02',
#   '경제통계학',
#   '강창희',
#   '3',
#   '3',
#   '화(13:30~14:45) / 목(13:30~14:45) / 310관 311호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '01478-03',
#   '경제통계학 (영어A강의)',
#   '최용옥',
#   '3',
#   '3',
#   '화(10:30~11:45) / 목(10:30~11:45) / 310관 311호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '11825-01',
#   '수리통계학(2) (영어A강의)',
#   '임창원',
#   '3',
#   '3',
#   '화(10:30~11:45) / 목(10:30~11:45) / 310관 503호 &#60;강의실&#62;',
#   '응용통계학과',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '11825-02',
#   '수리통계학(2) (영어A강의)',
#   '김원국',
#   '3',
#   '3',
#   '월(13:30~14:45) / 수(13:30~14:45) / 310관 503호 &#60;강의실&#62;',
#   '응용통계학과',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '11934-01',
#   '수치해석 (영어A강의)',
#   '김영삼',
#   '3',
#   '3',
#   '월3,4 / 수4 / 102관(약학대학 및 R&D센터) 109호 &#60;강의실&#62; / 805호 &#60;강의실&#62;',
#   '수학과',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '37669-01',
#   '이산시간금융공학',
#   None,
#   '3',
#   '3',
#   '목10,11,12 / 102관(약학대학 및 R&D센터) 805호 &#60;강의실&#62;',
#   '금융공학융합전공',
#   '융합전공 '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '18178-02',
#   '재무관리',
#   '유시용',
#   '3',
#   '3',
#   '월1,2,3 / 수1,2,3 / 310관 503호 &#60;강의실&#62;',
#   '경영학전공',
#   ' 유연학기(1주~8주)'],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '18178-04',
#   '재무관리',
#   '허석균',
#   '3',
#   '3',
#   '화(10:30~11:45) / 목(10:30~11:45) / 310관 921호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '18178-05',
#   '재무관리',
#   '김동순',
#   '3',
#   '3',
#   '월(10:30~11:45) / 수(10:30~11:45) / 310관 926호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '18178-01',
#   '재무관리 (영어A강의)',
#   '송수영',
#   '3',
#   '3',
#   '월7,8,9 / 수7,8,9 / 310관 804호 &#60;강의실&#62;',
#   '경영학전공',
#   ' 유연학기(9주~16주)'],
#  ['금융공학융합전공',
#   '2',
#   '전공필수',
#   '18178-03',
#   '재무관리 (영어A강의)',
#   '이관영',
#   '3',
#   '3',
#   '월(15:00~16:15) / 수(15:00~16:15) / 310관 922호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '27808-01',
#   '중급재무회계(Ⅱ)',
#   '전영순',
#   '3',
#   '3',
#   '월(15:00~16:15) / 수(15:00~16:15) / 310관 932호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '27808-02',
#   '중급재무회계(Ⅱ)',
#   '황인태',
#   '3',
#   '3',
#   '금1,2,3 / 310관 721호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '27808-03',
#   '중급재무회계(Ⅱ)',
#   '육지훈',
#   '3',
#   '3',
#   '화(10:30~11:45) / 목(10:30~11:45) / 310관 818호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '21961-01',
#   '투자론',
#   '오규택',
#   '3',
#   '3',
#   '화(09:00~10:15) / 목(09:00~10:15) / 310관 920호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '21961-02',
#   '투자론',
#   '오규택',
#   '3',
#   '3',
#   '화(10:30~11:45) / 목(10:30~11:45) / 310관 920호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '21961-03',
#   '투자론',
#   '오규택',
#   '3',
#   '3',
#   '금7,8,9 / 310관 920호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '2',
#   '전공',
#   '21961-04',
#   '투자론 (영어A강의)',
#   '정태규',
#   '3',
#   '3',
#   '수4,5,6 / 310관 505호 &#60;강의실&#62;',
#   '경영학전공',
#   ' '],
#  ['금융공학융합전공',
#   '3',
#   '전공',
#   '52320-01',
#   '웹프로그래밍 (영어A강의)',
#   '김상욱',
#   '3',
#   '3',
#   '목9,10,11 / 310관 728호 &#60;강의실&#62;',
#   '소프트웨어학부',
#   ' 자과생수강불가,SCSC,비전공자전용'],
#  ['금융공학융합전공',
#   '3',
#   '전공',
#   '54461-01',
#   '응용계량경제학',
#   '이광훈',
#   '3',
#   '3',
#   '월(10:30~11:45) / 수(10:30~11:45) / 310관 310호 &#60;강의실&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '3',
#   '전공',
#   '54461-02',
#   '응용계량경제학',
#   '진현정',
#   '3',
#   '3',
#   '화(10:30~11:45) / 목(10:30~11:45) / 310관 717호 &#60;컴퓨터실습실-2&#62;',
#   '경제학부(서울)',
#   ' '],
#  ['금융공학융합전공',
#   '3',
#   '전공',
#   '51280-01',
#   '휴먼ICT인공지능',
#   '김대원',
#   '3',
#   '3',
#   '금7,8,9 / 310관 B312호 &#60;SW융합 PC실4&#62;',
#   '소프트웨어학부',
#   ' 공학주제(설계1)'],
#  ['금융공학융합전공',
#   '3',
#   '전공',
#   '51280-02',
#   '휴먼ICT인공지능 (영어A강의)',
#   '이재성',
#   '3',
#   '3',
#   '월3,4 / 수3 / 310관 B310호 &#60;SW기초교양PC실1&#62;',
#   '소프트웨어학부',
#   ' 공학주제(설계1)'],
#  ['금융공학융합전공',
#   '4',
#   '전공',
#   '37671-01',
#   '금융공학실습(2)',
#   None,
#   '3',
#   '3',
#   '수10,11,12 / 102관(약학대학 및 R&D센터) 805호 &#60;강의실&#62;',
#   '금융공학융합전공',
#   '융합전공 '],
#  ['금융공학융합전공',
#   '4',
#   '전공',
#   '33675-01',
#   '금융수학 (영어A강의)',
#   '홍영훈',
#   '3',
#   '3',
#   '월5 / 수5,6 / 102관(약학대학 및 R&D센터) 805호 &#60;강의실&#62;',
#   '수학과',
#   ' ']]

# %%
susts

# %%
write_wb = Workbook()
write_ws = write_wb.active

for row in exportTable:
    write_ws.append(row)

write_wb.save('{}.csv'.format(colg['name']))

# %%
import requests, json
from bs4 import BeautifulSoup

from openpyxl import load_workbook
from openpyxl import Workbook

campfgs = ["1", "2"]

for campfg in campfgs:
    URL = "https://mportal.cau.ac.kr/std/usk/sUskSif001/selectParam.ajax"
    params = {'year': "2019", 'campfg': campfg, 'course': "3", 'gb': "3"}
    headers = {'Content-Type': 'application/json; charset=utf-8'}

    res = requests.post(URL, headers=headers, data=json.dumps(params))

    resToJson = res.json()
    
    # 교양 / 융합전공 / 연계전공 / --- / 대학들...
    colgList = []
    
    for menu in resToJson['selectColg']:
        if menu['deptcd'] == None:
            continue

        insertDict = {'name': menu['deptkornm'], 'code': menu['deptcd'], 'campcode': menu['campfg']}

        colgList.append(insertDict)
    
    
    # 대학들 마다 세부 전공 탐색
    for idx, colg in enumerate(colgList):
        URL = "https://mportal.cau.ac.kr/std/usk/sUskSif001/selectSust.ajax"
        params = {'year': "2019", 'campfg': campfg, 'course': "3", 'gb': "3", 'colgcd': colg['code'], 'shtm': "2"}
        headers = {'Content-Type': 'application/json; charset=utf-8'}

        res = requests.post(URL, headers=headers, data=json.dumps(params))
        resToJson = res.json()
        
        # 세부 전공들
        susts = []
        
        exportTable = []
        exportTable.append(['전공', '학년', '이수구분', '과목번호-분반', '과목명', '담당교수', '학점', '시간', '강의실/강의시간', '개설학과', '유의사항'])
        
        write_wb = Workbook()
        write_ws = write_wb.active
        
        for detailSust in resToJson['selectSust']:
            insertSust = {'campcode': detailSust['camp'], 'name': detailSust['nm'], 'code': detailSust['deptcd']}

            susts.append(insertSust)
        
        if idx < 3:
            search_gb = colg['code']
        else:
            search_gb = "ELSE"
        
        for sust in susts:
            URL = "https://mportal.cau.ac.kr/std/usk/sUskSif001/selectSbjt.ajax"
            params = {"year":"2019","campfg":campfg,"course":"3","gb":"3","colgcd":colg['code'], "shtm":"2", "sust":sust['code'], "search_gb": search_gb, "kornm":""}
            headers = {'Content-Type': 'application/json; charset=utf-8'}

            res = requests.post(URL, headers=headers, data=json.dumps(params))
            resToJson = res.json()

            for subject in resToJson['selectSust']:
                exportTable.append([sust['name'] \
                                    , subject['shyr'] \
                                    , subject['pobtnm'] \
                                    , subject['sbjtclss'] \
                                    , subject['clssnm'] \
                                    , subject['profnm'] \
                                    , subject['pnt'].split('-')[0] \
                                    , subject['pnt'].split('-')[1] \
                                    , subject['ltbdrm'] \
                                    , '' if subject['sustnm'] == None else subject['sustnm'] \
                                    , subject['remk']])

        for row in exportTable:
            write_ws.append(row)

        write_wb.save('{} - {}.csv'.format("서울캠퍼스" if campfg == "1" else "안성캠퍼스",colg['name']))
        
        print('{} - {} 파일 완료'.format("서울캠퍼스" if campfg == "1" else "안성캠퍼스",colg['name']))
# Out:
# 서울캠퍼스 - 교양 파일 완료
# 서울캠퍼스 - 연계전공 파일 완료
# 서울캠퍼스 - 융합전공 파일 완료
# 서울캠퍼스 - 인문대학(2011) 파일 완료
# 서울캠퍼스 - 사회과학대학(2011) 파일 완료
# 서울캠퍼스 - 사범대학(2011) 파일 완료
# 서울캠퍼스 - 자연과학대학(2011) 파일 완료
# 서울캠퍼스 - 공과대학(2011) 파일 완료
# 서울캠퍼스 - 창의ICT공과대학 파일 완료
# 서울캠퍼스 - 소프트웨어대학 파일 완료
# 서울캠퍼스 - 경영경제대학(2011) 파일 완료
# 서울캠퍼스 - 약학대학(2011) 파일 완료
# 서울캠퍼스 - 적십자간호대학(2011) 파일 완료
# 서울캠퍼스 - 적십자간호대학 파일 완료
# 서울캠퍼스 - 교양학부대학 파일 완료
# 서울캠퍼스 - 다빈치교양대학 파일 완료
# 서울캠퍼스 - 예술대학(2011) 파일 완료
# 서울캠퍼스 - 의과대학(2011) 파일 완료
# 서울캠퍼스 - 문과대학 파일 완료
# 서울캠퍼스 - 자연과학대학 파일 완료
# 서울캠퍼스 - 공과대학 파일 완료
# 서울캠퍼스 - 사범대학 파일 완료
# 서울캠퍼스 - 법과대학 파일 완료
# 서울캠퍼스 - 정경대학 파일 완료
# 서울캠퍼스 - 경영대학 파일 완료
# 서울캠퍼스 - 약학대학 파일 완료
# 서울캠퍼스 - 의과대학 파일 완료
# 서울캠퍼스 - 미디어공연영상대학 파일 완료
# 서울캠퍼스 - 자유전공학부. 파일 완료
# 서울캠퍼스 - 공공인재학부. 파일 완료
# 서울캠퍼스 - 글로벌지식학부. 파일 완료
# 서울캠퍼스 - 교양학부대학(2011) 파일 완료
# 안성캠퍼스 - 교양 파일 완료
# 안성캠퍼스 - 연계전공 파일 완료
# 안성캠퍼스 - 융합전공 파일 완료
# 안성캠퍼스 - 인문대학(2011) 파일 완료
# 안성캠퍼스 - 사회과학대학(2011) 파일 완료
# 안성캠퍼스 - 자연과학대학(2011) 파일 완료
# 안성캠퍼스 - 공과대학(2011) 파일 완료
# 안성캠퍼스 - 창의ICT공과대학 파일 완료
# 안성캠퍼스 - 경영경제대학(2011) 파일 완료
# 안성캠퍼스 - 교양학부대학 파일 완료
# 안성캠퍼스 - 다빈치교양대학 파일 완료
# 안성캠퍼스 - 예술대학(2011) 파일 완료
# 안성캠퍼스 - 체육대학(2011) 파일 완료
# 안성캠퍼스 - 생명공학대학 파일 완료
# 안성캠퍼스 - 예술공학대학 파일 완료
# 안성캠퍼스 - 산업과학대학 파일 완료
# 안성캠퍼스 - 예술대학 파일 완료
# 안성캠퍼스 - 외국어대학 파일 완료
# 안성캠퍼스 - 사회과학대학 파일 완료
# 안성캠퍼스 - 생활과학대학 파일 완료
# 안성캠퍼스 - 음악대학 파일 완료
# 안성캠퍼스 - 건설대학 파일 완료
# 안성캠퍼스 - 체육과학대학 파일 완료
# 안성캠퍼스 - 국악대학 파일 완료
# 안성캠퍼스 - 글로벌지식 학부. 파일 완료
# 안성캠퍼스 - 교양학부대학(2011) 파일 완료
